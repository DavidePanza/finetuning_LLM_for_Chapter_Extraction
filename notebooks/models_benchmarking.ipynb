# %% [markdown]
# # 🔬 Model Benchmarking and Comparison
#
# ## Purpose
# Compares the performance of the original Qwen3-0.6B base model against the fine-tuned version on TOC extraction tasks. Demonstrates how fine-tuning improves the model's ability to correctly extract page information and handle noisy inputs.
#
# <br>
#
# ---
#
# ## What This Notebook Does
#
# ### Model Loading
# - **Base model**: Loads the original `unsloth/Qwen3-0.6B-unsloth-bnb-4bit` for baseline comparison
# - **Fine-tuned model**: Loads the merged 16-bit fine-tuned model from previous training in 4bit
#
# ### Benchmarking Process
# - Tests both models on the same noisy TOC samples from the test dataset
# - Uses identical prompting strategies for fair comparison
#
# ### Key Improvements
# The fine-tuning results show the model has learned to:
# - **Extract accurate page ranges**: Calculates proper end_page values (next chapter start_page - 1)
# - **Handle noisy inputs**: More resistant to formatting inconsistencies, random characters, and OCR errors
# - **Maintain JSON structure**: Consistently outputs properly formatted JSON with required fields
# - **Ignore irrelevant content**: Filters out "Exercises", decorative elements, and standalone numbers as instructed

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth
else:
    # Do this only in Colab notebooks! Otherwise use pip install unsloth
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft trl triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf "datasets>=3.4.1" huggingface_hub hf_transfer
    # !pip install --no-deps unsloth

# %%
import pickle
import torch
from unsloth import FastLanguageModel
from google.colab import drive
drive.mount('/content/drive')

data_path = "/content/drive/MyDrive/Projects/Finetuning_TOC_Extractor/data/synthetic_toc_test.pkl"
with open(data_path, 'rb') as f:
    training_data = pickle.load(f)
# Out:
# <ipython-input-2-4281327468>:6: UserWarning: WARNING: Unsloth should be imported before trl, transformers, peft to ensure all optimizations are applied. Your code may run slower or encounter memory issues without these optimizations.
#
# Please restructure your imports with 'import unsloth' at the top of your file.
#   from unsloth.chat_templates import standardize_sharegpt
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Mounted at /content/drive

# %% [markdown]
# ## Model Loading for Comparison
#
# Loads both the original Qwen3-0.6B base model and the fine-tuned merged model for side-by-side performance comparison. Both models are loaded in 4-bit quantization with identical parameters to ensure fair benchmarking conditions.

# %%
model ="unsloth/Qwen3-0.6B-unsloth-bnb-4bit"

# Load model with Unsloth (handles 4-bit automatically)
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = model,
    max_seq_length = 2048,
    dtype=None,
    load_in_4bit = True,
    load_in_8bit = False,
    full_finetuning = False,
)

merged_16bit = "/path/to/your/merged_16bit_model"  # Replace with your actual path

model_finetuned, tokenizer_finetuned = FastLanguageModel.from_pretrained(
    model_name = merged_16bit,
    max_seq_length = 2048,
    dtype = None,
    load_in_4bit = True,
    )
# Out:
# ==((====))==  Unsloth 2025.6.2: Fast Qwen3 patching. Transformers: 4.52.4.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/576M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/237 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/4.67k [00:00<?, ?B/s]

# %% [markdown]
# ## Inference Functions Setup
#
# Defines standardized inference functions for consistent model comparison across both base and fine-tuned models. Includes prompt preparation with detailed TOC parsing instructions and a unified generation function with optimized parameters for reliable JSON output.

# %%
def prepare_inference_prompt(toc_text, tokenizer):
    system_prompt = """You are a table of contents parser. Read the input carefully and extract ONLY the numbered chapters shown.

CRITICAL INSTRUCTIONS:
1. Read the provided table of contents line by line
2. Find lines that match: NUMBER SPACE TITLE PAGE_NUMBER
3. Extract the exact chapter titles from the input text
4. Use the exact page numbers from the input text
5. Calculate end_page = next chapter start_page - 1
6. Ignore lines with "Exercises", "###", "•", or standalone numbers

FORMAT: Return JSON array with: chapter_number, chapter_title, start_page, end_page
"""

    messages = [
        {"role": "system", "content": system_prompt},
        {
            "role": "user",
            "content": f"""Parse this specific table of contents and extract the numbered chapters:

{toc_text.strip()}

Extract the chapters from the text above (not from any other source):"""
        }
    ]

    return tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True,
        enable_thinking=False
    )


# Usage remains the same
def extract_chapters(model, tokenizer, toc_text):
    # Enable inference mode
    FastLanguageModel.for_inference(model)

    # Prepare the prompt
    prompt = prepare_inference_prompt(toc_text, tokenizer)

    # Tokenize and move to same device as model
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    # Generate
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=1024,
            temperature=0.1,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id,
            eos_token_id=tokenizer.eos_token_id,
        )

    # Extract only the generated part
    new_tokens = outputs[0][inputs['input_ids'].shape[1]:]
    json_output = tokenizer.decode(new_tokens, skip_special_tokens=True)

    return json_output.strip()

# %% [markdown]
# # Benchmarking Loop and Results
#
# Runs side-by-side comparison tests on multiple noisy TOC samples, displaying both models' outputs for direct performance evaluation. Demonstrates the fine-tuned model's superior ability to extract proper page ranges and maintain JSON formatting compared to the base model.

# %%
for idx in range(11,17):
  train_sample = training_data[idx][0]
  print("\n\n\nnew sample:\n")
  print(train_sample)

  output_original = extract_chapters(model, tokenizer, train_sample)
  #output_original = extract_chapters(model, tokenizer, train_sample)
  output_finetuned = extract_chapters(model_finetuned, tokenizer_finetuned, train_sample)

  print("original\n")
  print(output_original)
  print("\nfinetuned")
  print(output_finetuned)
# Out:
# new sample:
#
# 1 Dragon Subspecies Classification Systems  1
# Exercises
# 2 Mating Rituals and Reproductive Cycles   25
# Exercises
# 3 Wing Aerodynamics and Flight Patterns 68
# Exercises
# 4 Magical Influence on Surrounding Ecosystems 117
# Exercises
# 5 Symbiotic Relationships with Other Creatures  134
# Exercises
# 6 Aging Processes and Lifespan Variations      154
# Exercises
# 7 Territorial Behavior and Nesting Habits   191
#  Break-even analysis and sensitivity testing procedures
# Exercises
# 8 Hoard Psychology and Treasure Selection 217
# Exercises
# 9 Magical Energy Metabolism and Storage  241
# Exercises
# 10 Interaction Protocols with Human Settlements 258
# Exercises
# 1
# 11 Dietary Requirements and Hunting Strategies 284
# Exercises
# 12 Fire Production Mechanisms and Organ Structure 320
# Exercises
# 13 Environmental Adaptations Across Climates 355
# Exercises
#
# original
#
# ```json
# [
#   {
#     "chapter_number": 1,
#     "chapter_title": "Dragon Subspecies Classification Systems",
#     "start_page": 1,
#     "end_page": 1
#   },
#   {
#     "chapter_number": 2,
#     "chapter_title": "Mating Rituals and Reproductive Cycles",
#     "start_page": 25,
#     "end_page": 25
#   },
#   {
#     "chapter_number": 3,
#     "chapter_title": "Wing Aerodynamics and Flight Patterns",
#     "start_page": 68,
#     "end_page": 68
#   },
#   {
#     "chapter_number": 4,
#     "chapter_title": "Magical Influence on Surrounding Ecosystems",
#     "start_page": 117,
#     "end_page": 117
#   },
#   {
#     "chapter_number": 5,
#     "chapter_title": "Symbiotic Relationships with Other Creatures",
#     "start_page": 134,
#     "end_page": 134
#   },
#   {
#     "chapter_number": 6,
#     "chapter_title": "Aging Processes and Lifespan Variations",
#     "start_page": 154,
#     "end_page": 154
#   },
#   {
#     "chapter_number": 7,
#     "chapter_title": "Territorial Behavior and Nesting Habits",
#     "start_page": 191,
#     "end_page": 191
#   },
#   {
#     "chapter_number": 11,
#     "chapter_title": "Break-even analysis and sensitivity testing procedures",
#     "start_page": 284,
#     "end_page": 284
#   },
#   {
#     "chapter_number": 12,
#     "chapter_title": "Hoard Psychology and Treasure Selection",
#     "start_page": 217,
#     "end_page": 217
#   },
#   {
#     "chapter_number": 13,
#     "chapter_title": "Magical Energy Metabolism and Storage",
#     "start_page": 241,
#     "end_page": 241
#   },
#   {
#     "chapter_number": 14,
#     "chapter_title": "Interaction Protocols with Human Settlements",
#     "start_page": 258,
#     "end_page": 258
#   }
# ]
# ```
#
# finetuned
# ```json
# [
# {"chapter_number": "1", "chapter_title": "Dragon Subspecies Classification Systems", "start_page": "1", "end_page": "24"},
# {"chapter_number": "2", "chapter_title": "Mating Rituals and Reproductive Cycles", "start_page": "25", "end_page": "67"},
# {"chapter_number": "3", "chapter_title": "Wing Aerodynamics and Flight Patterns", "start_page": "68", "end_page": "116"},
# {"chapter_number": "4", "chapter_title": "Magical Influence on Surrounding Ecosystems", "start_page": "117", "end_page": "133"},
# {"chapter_number": "5", "chapter_title": "Symbiotic Relationships with Other Creatures", "start_page": "134", "end_page": "153"},
# {"chapter_number": "6", "chapter_title": "Aging Processes and Lifespan Variations", "start_page": "154", "end_page": "190"},
# {"chapter_number": "7", "chapter_title": "Territorial Behavior and Nesting Habits", "start_page": "191", "end_page": "216"},
# {"chapter_number": "8", "chapter_title": "Hoard Psychology and Treasure Selection", "start_page": "217", "end_page": "240"},
# {"chapter_number": "9", "chapter_title": "Magical Energy Metabolism and Storage", "start_page": "241", "end_page": "257"},
# {"chapter_number": "10", "chapter_title": "Interaction Protocols with Human Settlements", "start_page": "258", "end_page": "283"},
# {"chapter_number": "11", "chapter_title": "Dietary Requirements and Hunting Strategies", "start_page": "284", "end_page": "319"},
# {"chapter_number": "12", "chapter_title": "Fire Production Mechanisms and Organ Structure", "start_page": "320", "end_page": "354"},
# {"chapter_number": "13", "chapter_title": "Environmental Adaptations Across Climates", "start_page": "355", "end_page": "375}
# ]
# ```
#
#
#
# new sample:
#
# 1 Manufacturing Processes for Precision Components
# 2
# 2 Combustion Chamber Fuel Injection Systems
#      47
# 3 Environmental Impact Assessment and Emissions
#    84
# 4 Compressor Blade Design and Optimization
# 101
# 5 Materials Science for High-Temperature Applications
#    122
# 6 Computational Fluid Dynamics in Engine Design
#  149
# 7 Maintenance Scheduling and Predictive Analytics
# 178
# 8 Turbine Cooling Technologies and Heat Management
#  217
# 9 Quality Assurance and Testing Protocols
#      237
#
# original
#
# ```json
# [
#   {
#     "chapter_number": 1,
#     "chapter_title": "Manufacturing Processes for Precision Components",
#     "start_page": 1,
#     "end_page": 0
#   },
#   {
#     "chapter_number": 2,
#     "chapter_title": "Combustion Chamber Fuel Injection Systems",
#     "start_page": 47,
#     "end_page": 47
#   },
#   {
#     "chapter_number": 3,
#     "chapter_title": "Environmental Impact Assessment and Emissions",
#     "start_page": 84,
#     "end_page": 84
#   },
#   {
#     "chapter_number": 4,
#     "chapter_title": "Compressor Blade Design and Optimization",
#     "start_page": 101,
#     "end_page": 101
#   },
#   {
#     "chapter_number": 5,
#     "chapter_title": "Materials Science for High-Temperature Applications",
#     "start_page": 122,
#     "end_page": 122
#   },
#   {
#     "chapter_number": 6,
#     "chapter_title": "Computational Fluid Dynamics in Engine Design",
#     "start_page": 149,
#     "end_page": 149
#   },
#   {
#     "chapter_number": 7,
#     "chapter_title": "Maintenance Scheduling and Predictive Analytics",
#     "start_page": 178,
#     "end_page": 178
#   },
#   {
#     "chapter_number": 8,
#     "chapter_title": "Turbine Cooling Technologies and Heat Management",
#     "start_page": 217,
#     "end_page": 217
#   }
# ]
# ```
#
# finetuned
# ```json
# [
# {"chapter_number": "1", "chapter_title": "Manufacturing Processes for Precision Components", "start_page": 1, "end_page": 46},
# {"chapter_number": "2", "chapter_title": "Combustion Chamber Fuel Injection Systems", "start_page": 47, "end_page": 83},
# {"chapter_number": "3", "chapter_title": "Environmental Impact Assessment and Emissions", "start_page": 84, "end_page": 100},
# {"chapter_number": "4", "chapter_title": "Compressor Blade Design and Optimization", "start_page": 101, "end_page": 121},
# {"chapter_number": "5", "chapter_title": "Materials Science for High-Temperature Applications", "start_page": 122, "end_page": 148},
# {"chapter_number": "6", "chapter_title": "Computational Fluid Dynamics in Engine Design", "start_page": 149, "end_page": 177},
# {"chapter_number": "7", "chapter_title": "Maintenance Scheduling and Predictive Analytics", "start_page": 178, "end_page": 216},
# {"chapter_number": "8", "chapter_title": "Turbine Cooling Technologies and Heat Management", "start_page": 217, "end_page": 236},
# {"chapter_number": "9", "chapter_title": "Quality Assurance and Testing Protocols", "start_page": 237, "end_page": 260}
# ]
# ```
#
#
#
# new sample:
#
# 1 Tool Selection and Workshop Organization
#  3
# 2 Budget Planning and Project Timeline Management
#  34
# 3 Paint Preparation and Period-Correct Color Matching
# 58
# 4 Show Preparation and Judging Criteria
# 98
# 11
# 5 Bodywork Rust Assessment and Metal Fabrication
#      153
# 6 Engine Rebuilding Techniques and Machining
# 178
# 7 Suspension System Overhaul and Alignment
#     192
# 83
# 8 Transmission and Drivetrain Restoration
# 221
# 9 Fuel System Cleaning and Carburetor Rebuilding
# 269
# 10 Electrical System Rewiring and Component Sourcing
#    275
#
# original
#
# ```json
# [
#   {
#     "chapter_number": 1,
#     "chapter_title": "Tool Selection and Workshop Organization",
#     "start_page": 3,
#     "end_page": 3
#   },
#   {
#     "chapter_number": 2,
#     "chapter_title": "Budget Planning and Project Timeline Management",
#     "start_page": 34,
#     "end_page": 34
#   },
#   {
#     "chapter_number": 3,
#     "chapter_title": "Paint Preparation and Period-Correct Color Matching",
#     "start_page": 58,
#     "end_page": 58
#   },
#   {
#     "chapter_number": 4,
#     "chapter_title": "Show Preparation and Judging Criteria",
#     "start_page": 98,
#     "end_page": 98
#   },
#   {
#     "chapter_number": 11,
#     "chapter_title": "Bodywork Rust Assessment and Metal Fabrication",
#     "start_page": 153,
#     "end_page": 153
#   },
#   {
#     "chapter_number": 5,
#     "chapter_title": "Engine Rebuilding Techniques and Machining",
#     "start_page": 178,
#     "end_page": 178
#   },
#   {
#     "chapter_number": 7,
#     "chapter_title": "Suspension System Overhaul and Alignment",
#     "start_page": 192,
#     "end_page": 192
#   },
#   {
#     "chapter_number": 8,
#     "chapter_title": "Transmission and Drivetrain Restoration",
#     "start_page": 221,
#     "end_page": 221
#   },
#   {
#     "chapter_number": 9,
#     "chapter_title": "Fuel System Cleaning and Carburetor Rebuilding",
#     "start_page": 269,
#     "end_page": 269
#   },
#   {
#     "chapter_number": 10,
#     "chapter_title": "Electrical System Rewiring and Component Sourcing",
#     "start_page": 275,
#     "end_page": 275
#   }
# ]
# ```
#
# finetuned
# ```json
# [
# {"chapter_number": "1", "chapter_title": "Tool Selection and Workshop Organization", "start_page": 3, "end_page": 33},
# {"chapter_number": "2", "chapter_title": "Budget Planning and Project Timeline Management", "start_page": 34, "end_page": 57},
# {"chapter_number": "3", "chapter_title": "Paint Preparation and Period-Correct Color Matching", "start_page": 58, "end_page": 97},
# {"chapter_number": "4", "chapter_title": "Show Preparation and Judging Criteria", "start_page": 98, "end_page": 152},
# {"chapter_number": "5", "chapter_title": "Bodywork Rust Assessment and Metal Fabrication", "start_page": 153, "end_page": 177},
# {"chapter_number": "6", "chapter_title": "Engine Rebuilding Techniques and Machining", "start_page": 178, "end_page": 220},
# {"chapter_number": "7", "chapter_title": "Suspension System Overhaul and Alignment", "start_page": 221, "end_page": 220},
# {"chapter_number": "8", "chapter_title": "Transmission and Drivetrain Restoration", "start_page": 221, "end_page": 268},
# {"chapter_number": "9", "chapter_title": "Fuel System Cleaning and Carburetor Rebuilding", "start_page": 269, "end_page": 274},
# {"chapter_number": "10", "chapter_title": "Electrical System Rewiring and Component Sourcing", "start_page": 275, "end_page": 290}
# ]
# ```
#
#
#
# new sample:
#
# 1. Actuator Systems and Motion Control 2
# 2. Robotic Arm Programming and Path Planning 37
# ###############
# 3. SCADA Systems and Remote Monitoring  97
# 4. Conveyor System Design and Material Handling    118
# 5. Energy Efficiency Optimization   128
# 6. Cybersecurity in Industrial Networks      152
#
# original
#
# ```json
# [
#   {
#     "chapter_number": 1,
#     "chapter_title": "Actuator Systems and Motion Control",
#     "start_page": 1,
#     "end_page": 1
#   },
#   {
#     "chapter_number": 2,
#     "chapter_title": "Robotic Arm Programming and Path Planning",
#     "start_page": 37,
#     "end_page": 37
#   },
#   {
#     "chapter_number": 3,
#     "chapter_title": "SCADA Systems and Remote Monitoring",
#     "start_page": 97,
#     "end_page": 97
#   },
#   {
#     "chapter_number": 4,
#     "chapter_title": "Conveyor System Design and Material Handling",
#     "start_page": 118,
#     "end_page": 118
#   },
#   {
#     "chapter_number": 5,
#     "chapter_title": "Energy Efficiency Optimization",
#     "start_page": 128,
#     "end_page": 128
#   },
#   {
#     "chapter_number": 6,
#     "chapter_title": "Cybersecurity in Industrial Networks",
#     "start_page": 152,
#     "end_page": 152
#   }
# ]
# ```
#
# finetuned
# ```json
# [
# {"chapter_number": "1", "chapter_title": "Actuator Systems and Motion Control", "start_page": 2, "end_page": 36},
# {"chapter_number": "2", "chapter_title": "Robotic Arm Programming and Path Planning", "start_page": 37, "end_page": 96},
# {"chapter_number": "3", "chapter_title": "SCADA Systems and Remote Monitoring", "start_page": 97, "end_page": 117},
# {"chapter_number": "4", "chapter_title": "Conveyor System Design and Material Handling", "start_page": 118, "end_page": 127},
# {"chapter_number": "5", "chapter_title": "Energy Efficiency Optimization", "start_page": 128, "end_page": 151},
# {"chapter_number": "6", "chapter_title": "Cybersecurity in Industrial Networks", "start_page": 152, "end_page": 173}
# ]
# ```
#
#
#
# new sample:
#
# chapter 1 Emergency Repair Procedures 3
# chapter 2 Backflow Prevention and Cross-Connection Control 63
# chapter 3 Hot Water Heater Installation and Maintenance 83
# chapter 4 Gas Line Installation and Safety Protocols 103
# chapter 5 Hydronic Heating System Installation      139
# chapter 6 Septic System Design and Maintenance 182
# • • • • • • • •
# chapter 7 Green Plumbing Technologies and Water Conservation      202
#
# original
#
# ```json
# [
#   {
#     "chapter_number": 1,
#     "chapter_title": "Emergency Repair Procedures",
#     "start_page": 3,
#     "end_page": 3
#   },
#   {
#     "chapter_number": 2,
#     "chapter_title": "Backflow Prevention and Cross-Connection Control",
#     "start_page": 63,
#     "end_page": 63
#   },
#   {
#     "chapter_number": 3,
#     "chapter_title": "Hot Water Heater Installation and Maintenance",
#     "start_page": 83,
#     "end_page": 83
#   },
#   {
#     "chapter_number": 4,
#     "chapter_title": "Gas Line Installation and Safety Protocols",
#     "start_page": 103,
#     "end_page": 103
#   },
#   {
#     "chapter_number": 5,
#     "chapter_title": "Hydronic Heating System Installation",
#     "start_page": 139,
#     "end_page": 139
#   },
#   {
#     "chapter_number": 6,
#     "chapter_title": "Septic System Design and Maintenance",
#     "start_page": 182,
#     "end_page": 182
#   },
#   {
#     "chapter_number": 7,
#     "chapter_title": "Green Plumbing Technologies and Water Conservation",
#     "start_page": 202,
#     "end_page": 202
#   }
# ]
# ```
#
# finetuned
# ```json
# [
# {"chapter_number": "1", "chapter_title": "Emergency Repair Procedures", "start_page": "3", "end_page": "62"},
# {"chapter_number": "2", "chapter_title": "Backflow Prevention and Cross-Connection Control", "start_page": "63", "end_page": "82"},
# {"chapter_number": "3", "chapter_title": "Hot Water Heater Installation and Maintenance", "start_page": "83", "end_page": "102"},
# {"chapter_number": "4", "chapter_title": "Gas Line Installation and Safety Protocols", "start_page": "103", "end_page": "138"},
# {"chapter_number": "5", "chapter_title": "Hydronic Heating System Installation", "start_page": "139", "end_page": "181"},
# {"chapter_number": "6", "chapter_title": "Septic System Design and Maintenance", "start_page": "182", "end_page": "201"},
# {"chapter_number": "7", "chapter_title": "Green Plumbing Technologies and Water Conservation", "start_page": "202", "end_page": "220}
# ]
# ```
#
#
#
# new sample:
#
# 1 Wood Finishing Techniques and Surface Preparation 2
# 2 Inlay and Marquetry Artistic Techniques    32
# 3 Shop Organization and Dust Collection 49
# 4 Curved Work and Steam Bending Methods 58
# 5 Troubleshooting Common Woodworking Problems   85
# 6 Mortise and Tenon Joint Precision Cutting 141
# 7 Measuring and Marking Accuracy Methods  195
# 8 Glue Selection and Clamping Strategies 229
# 9 Wood Movement and Seasonal Adjustment Design 246
# 4
#
# original
#
# ```json
# [
#   {
#     "chapter_number": 1,
#     "chapter_title": "Wood Finishing Techniques and Surface Preparation",
#     "start_page": 1,
#     "end_page": 1
#   },
#   {
#     "chapter_number": 2,
#     "chapter_title": "Inlay and Marquetry Artistic Techniques",
#     "start_page": 32,
#     "end_page": 32
#   },
#   {
#     "chapter_number": 3,
#     "chapter_title": "Shop Organization and Dust Collection",
#     "start_page": 49,
#     "end_page": 49
#   },
#   {
#     "chapter_number": 4,
#     "chapter_title": "Curved Work and Steam Bending Methods",
#     "start_page": 58,
#     "end_page": 58
#   },
#   {
#     "chapter_number": 5,
#     "chapter_title": "Troubleshooting Common Woodworking Problems",
#     "start_page": 85,
#     "end_page": 85
#   },
#   {
#     "chapter_number": 6,
#     "chapter_title": "Mortise and Tenon Joint Precision Cutting",
#     "start_page": 141,
#     "end_page": 141
#   },
#   {
#     "chapter_number": 7,
#     "chapter_title": "Measuring and Marking Accuracy Methods",
#     "start_page": 195,
#     "end_page": 195
#   },
#   {
#     "chapter_number": 8,
#     "chapter_title": "Glue Selection and Clamping Strategies",
#     "start_page": 229,
#     "end_page": 229
#   }
# ]
# ```
#
# finetuned
# ```json
# [
# {"chapter_number": "1", "chapter_title": "Wood Finishing Techniques and Surface Preparation", "start_page": 2, "end_page": 31},
# {"chapter_number": "2", "chapter_title": "Inlay and Marquetry Artistic Techniques", "start_page": 32, "end_page": 48},
# {"chapter_number": "3", "chapter_title": "Shop Organization and Dust Collection", "start_page": 49, "end_page": 57},
# {"chapter_number": "4", "chapter_title": "Curved Work and Steam Bending Methods", "start_page": 58, "end_page": 84},
# {"chapter_number": "5", "chapter_title": "Troubleshooting Common Woodworking Problems", "start_page": 85, "end_page": 140},
# {"chapter_number": "6", "chapter_title": "Mortise and Tenon Joint Precision Cutting", "start_page": 141, "end_page": 194},
# {"chapter_number": "7", "chapter_title": "Measuring and Marking Accuracy Methods", "start_page": 195, "end_page": 228},
# {"chapter_number": "8", "chapter_title": "Glue Selection and Clamping Strategies", "start_page": 229, "end_page": 245},
# {"chapter_number": "9", "chapter_title": "Wood Movement and Seasonal Adjustment Design", "start_page": 246, "end_page": 269}
# ]
# ```
